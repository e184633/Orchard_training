# %% [markdown]
# # Solutions to matplotlib and seaborn exercises

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Question 1
# create a bar chart of Pokemon species introduced by generation.

# %%
# data setup
pokemon = pd.read_csv('../Exercises/data/pokemon.csv')
fuel_econ = pd.read_csv('../Exercises/data/fuel_econ.csv')

# %% [markdown]
# ## Question 2
#
# create a histogram of Pokemon special defense values.

# %% [markdown]
# ## Question 3
#
# create a histogram of Pokemon heights and weights.
#
# There's a very long tail of Pokemon heights. Here, I've focused in on Pokemon of height 6 meters or less, so that I can use a smaller bin size to get a more detailed look at the main data distribution.

# %%
# Out:
# Text(0.5,0,'Weight (kg)')

# %% [markdown]
# ## Question 4
# create a scatterplot of city vs. highway fuel mileage.

# %%
# Out:
# Text(0,0.5,'Highway Fuel Eff. (mpg)')

# %% [markdown]
# ## Question 5
#
# create a heat map of engine displacement vs. co2 production.
# Try to interpret results you see.

# %% [markdown]
# ## Question 6
#
# plot the relationship between vehicle class and engine displacement.

# %% [markdown]
# ## Question 7
#
# plot the average combined fuel efficiency for each manufacturer with at least 80 cars.
